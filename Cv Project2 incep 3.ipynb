# %%
import os
import sys
import time
from glob import glob
from tqdm.notebook import tqdm

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pandas as pd

import cv2
from PIL import Image
import shutil

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import f1_score

# TensorFlow Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.applications import Xception
from tensorflow.keras import layers, models

from IPython.display import YouTubeVideo
import albumentations as A
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

print('All modules have been imported')
# Out:
# All modules have been imported

# %%
base_skin_dir = "F:/CV/skin/images"

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}
print(imageid_path_dict)
# Out:
# {}

# %%
base_skin_dir = "F:/CV/skin/images"

#imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
#                     for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}

lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

tile_df = pd.read_csv("F:/CV/skin/HAM10000_metadata.csv")
tile_df['path'] = tile_df['image_id'].apply(lambda x: os.path.join(base_skin_dir, f"{x}.jpg"))
tile_df['cell_type'] = tile_df['dx'].map(lesion_type_dict.get) 
tile_df['cell_type_idx'] = pd.Categorical(tile_df['cell_type']).codes
tile_df.sample(5)
# Out:
#         lesion_id      image_id  dx    dx_type   age     sex     localization  \
# 8790  HAM_0002154  ISIC_0028478  nv      histo  70.0    male            chest
# 3987  HAM_0001771  ISIC_0030556  nv  follow_up  55.0    male            trunk
# 5380  HAM_0001032  ISIC_0028321  nv  follow_up  55.0    male          abdomen
# 7691  HAM_0006496  ISIC_0033104  nv      histo  55.0  female  lower extremity
# 6840  HAM_0006853  ISIC_0031863  nv      histo  50.0    male  lower extremity
#
#                                     path         cell_type  cell_type_idx
# 8790  F:/CV/skin/images\ISIC_0028478.jpg  Melanocytic nevi              4
# 3987  F:/CV/skin/images\ISIC_0030556.jpg  Melanocytic nevi              4
# 5380  F:/CV/skin/images\ISIC_0028321.jpg  Melanocytic nevi              4
# 7691  F:/CV/skin/images\ISIC_0033104.jpg  Melanocytic nevi              4
# 6840  F:/CV/skin/images\ISIC_0031863.jpg  Melanocytic nevi              4

# %%
df = pd.DataFrame() # columns=["filepaths", "labels"]

df['filepaths'] =tile_df['path']
df['labels'] =tile_df['cell_type_idx']
df['labels'] =df['labels'].apply(lambda x: str(x))
df.head()
# Out:
#                             filepaths labels
# 0  F:/CV/skin/images\ISIC_0027419.jpg      2
# 1  F:/CV/skin/images\ISIC_0025030.jpg      2
# 2  F:/CV/skin/images\ISIC_0026769.jpg      2
# 3  F:/CV/skin/images\ISIC_0025661.jpg      2
# 4  F:/CV/skin/images\ISIC_0031633.jpg      2

# %%
df.labels.unique()
# Out:
# array(['2', '4', '3', '5', '6', '1', '0'], dtype=object)

# %%
def split_df(df, trsize, column):
    train_df, dummy_df = train_test_split(df, train_size=trsize, shuffle=True, random_state=14, stratify=df[column])
    valid_df, test_df= train_test_split(dummy_df, train_size=.5, shuffle=True, random_state=14, stratify=dummy_df[column])
    print('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df)) 
    return train_df, test_df, valid_df    

train_df, test_df, valid_df  = split_df(df, .8, 'labels')
# Out:
# train_df length:  8012   test_df length:  1002   valid_df length:  1001

# %%
def plot_label_count (df, plot_title):
    column='labels'
    xaxis_label='CLASS'
    yaxis_label='IMAGE COUNT'
    vcounts=df[column].value_counts()
    labels=vcounts.keys().tolist()    
    values=vcounts.tolist() 
    lcount=len(labels)
    if lcount>55:
        print_in_color('The number of labels is >55, no plot will be produced')
    else:
        width=lcount * 4
        width=np.min([width, 20])
        plt.figure(figsize=(width,5)) 
        form = {'family': 'serif', 'color': 'blue', 'size': 25} 
        plt.bar(labels, values)
        plt.title(plot_title, fontsize= 24, color='blue')
        plt.xticks(rotation=90, fontsize=18)
        plt.yticks(fontsize=18)
        plt.xlabel(xaxis_label, fontdict=form)
        plt.ylabel(yaxis_label, fontdict=form)
        if lcount >=8:
            rotation='vertical'
        else:
            rotation='horizontal'
        for i in range(lcount):
            plt.text(i, values[i]/2, str(values[i]),fontsize=12, rotation=rotation, color='yellow', ha='center')        
        plt.show()

# %%
count=train_df['labels'].value_counts()
print (count)
plot_title='Initial Train Data Frame Label Count'
plot_label_count (train_df, plot_title)
# Out:
# labels
# 4    5364
# 5     890
# 2     879
# 1     411
# 0     262
# 6     114
# 3      92
# Name: count, dtype: int64

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    classes= df[column].unique()
    print(classes)
    class_count=len(classes)
    length=len(df)
    print ('dataframe initially is of length ',length, ' with ', class_count, ' classes')
    groups=df.groupby(column)    
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique(): 
        group=groups.get_group(label)
        count=len(group)    
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group        
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    classes=trimmed_df[column].unique()# return this in case some classes have less than min_samples
    class_count=len(classes) # return this in case some classes have less than min_samples
    length=len(trimmed_df)
    print ('the trimmed dataframe now is of length ',length, ' with ', class_count, ' classes')
    return trimmed_df, classes, class_count

max_samples=500
min_samples= 10
column='labels'
train_df, classes, class_count= trim(train_df, max_samples, min_samples, column)
# Out:
# ['4' '5' '0' '1' '2' '6' '3']
# dataframe initially is of length  8012  with  7  classes
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  10
# the trimmed dataframe now is of length  2379  with  7  classes

# %%
def balance(df, n,column, working_dir, img_size):
    def get_augmented_image(image):
        width=int(image.shape[1]*.8)
        height=int(image.shape[0]*.8)
        transform= A.Compose([
            A.HorizontalFlip(p=.5),
            A.Rotate(limit=30, p=.25),
            A.RandomBrightnessContrast(p=.5),
            A.RandomGamma(p=.5),
            A.RandomCrop(width=width, height=height, p=.25) ])    
        return transform(image=image)['image']
    def dummy(image):
        return image

    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df[column].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images  
    total=0    
    groups=df.groupby(column) # group by class
    for label in df[column].unique():  # for every class               
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count=len(group)   # determine how many samples there are in this class  
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images            
            desc=f'augmenting class {label}'
            for i in tqdm(range(delta), ncols=120, unit='files', colour='blue',desc=desc):
                j= i % sample_count
                img_path=group['filepaths'].iloc[j]
                img=cv2.imread(img_path)
                img=get_augmented_image(img)
                fname=os.path.basename(img_path)
                fname='aug' +str(i) +'-' +fname
                dest_path=os.path.join(target_dir, fname)                
                cv2.imwrite(dest_path, img)
                aug_img_count +=1
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=sorted(os.listdir(aug_dir))
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)     
        flist=sorted(os.listdir(classpath))    
        for f in flist:        
            fpath=os.path.join(classpath,f)         
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')   
    aug_df=pd.concat([Fseries, Lseries], axis=1)         
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df 

n=500
working_dir=r'F:/CV/working'
img_size = (310,640)
column='labels'
train_df=balance(train_df, n,column, working_dir, img_size)
# Out:
# Initial length of dataframe is  2379
# augmenting class 0:   0%|                                                                    | 0/238 [00:00<?,…
# augmenting class 1:   0%|                                                                     | 0/89 [00:00<?,…
# augmenting class 6:   0%|                                                                    | 0/386 [00:00<?,…
# augmenting class 3:   0%|                                                                    | 0/408 [00:00<?,…
# Total Augmented images created=  1121
# Length of augmented dataframe is now  3500

# %%
plot_title='Train DataFrame Label Count After Trimming and Balancing'
plot_label_count (train_df, plot_title)

# %%
def make_gens(batch_size, ycol, train_df, test_df, valid_df, img_size):
    trgen=ImageDataGenerator(horizontal_flip=True)    
    t_and_v_gen=ImageDataGenerator()
    msg='{0:70s} for train generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col=ycol, target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    msg='{0:70s} for valid generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col=ycol, target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    # for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
    # this insures that we go through all the sample in the test set exactly once.
    length=len(test_df)
    test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
    test_steps=int(length/test_batch_size)    
    msg='{0:70s} for test generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col=ycol, target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
    # from the generator we can get information we will need later
    classes=list(train_gen.class_indices.keys())
    class_indices=list(train_gen.class_indices.values())
    class_count=len(classes)
    labels=test_gen.labels
    print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
    return train_gen, test_gen, valid_gen, test_steps

bs=16
ycol='labels'
train_gen, test_gen, valid_gen, test_steps = make_gens(bs, ycol, train_df, test_df, valid_df, img_size)
# Out:
# Found 3500 validated image filenames belonging to 7 classes.           for train generator
# Found 1001 validated image filenames belonging to 7 classes.           for valid generator
# Found 1002 validated image filenames belonging to 7 classes.           for test generator
# test batch size:  6   test steps:  167  number of classes :  7

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(25, 25))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image=images[i] /255       
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=18)
        plt.axis('off')
    plt.show()
    
show_image_samples(train_gen )

# %%
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
img_shape=(img_size[0], img_size[1], 3)

# %%
base_model = tf.keras.applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=img_shape, pooling='max')

# %%
base_model.trainable= True

# %%
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                    bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
    # Evidential Begins
initial_learning_rate = 0.01
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.9,
    staircase=True)

#optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
#model.compile(optimizer=optimizer, loss='categorical_crossentropy',metrics=['accuracy', F1_score, 'AUC'])
model.compile(Adamax(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy', F1_score, 'AUC'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 310, 640, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 154, 319, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 154, 319, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 154, 319, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 152, 317, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 152, 317, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 152, 317, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 152, 317, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 152, 317, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 152, 317, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 75, 158, 64)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 75, 158, 80)  5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 75, 158, 80)  240        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 75, 158, 80)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 73, 156, 192  138240      ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 73, 156, 192  576        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 73, 156, 192  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 36, 77, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 36, 77, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 36, 77, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 36, 77, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 36, 77, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 36, 77, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 36, 77, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 36, 77, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 36, 77, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 36, 77, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 36, 77, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 36, 77, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 36, 77, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 36, 77, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 36, 77, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 36, 77, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 36, 77, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 36, 77, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 36, 77, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 36, 77, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 36, 77, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 36, 77, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 36, 77, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 36, 77, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 36, 77, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 36, 77, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 36, 77, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 36, 77, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 36, 77, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 36, 77, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 36, 77, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 36, 77, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 36, 77, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 36, 77, 320)  0           ['block35_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 36, 77, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 36, 77, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 36, 77, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 36, 77, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 36, 77, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 36, 77, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 36, 77, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 36, 77, 320)  0           ['block35_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 36, 77, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 36, 77, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 36, 77, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 36, 77, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 36, 77, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 36, 77, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 36, 77, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 36, 77, 320)  0           ['block35_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 36, 77, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 36, 77, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 36, 77, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 36, 77, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 36, 77, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 36, 77, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 36, 77, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 36, 77, 320)  0           ['block35_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 36, 77, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 36, 77, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 36, 77, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 36, 77, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 36, 77, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 36, 77, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 36, 77, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 36, 77, 320)  0           ['block35_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 36, 77, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 36, 77, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 36, 77, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 36, 77, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 36, 77, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 36, 77, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 36, 77, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 36, 77, 320)  0           ['block35_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 36, 77, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 36, 77, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 36, 77, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 36, 77, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 36, 77, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 36, 77, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 36, 77, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 36, 77, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 36, 77, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 36, 77, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 36, 77, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 36, 77, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 36, 77, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 36, 77, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 36, 77, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 36, 77, 320)  0           ['block35_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 36, 77, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 36, 77, 32)  96          ['conv2d_57[0][0]']
# ...
#
#  activation_189 (Activation)    (None, 8, 18, 224)   0           ['batch_normalization_189[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_6_ac[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 8, 18, 256)   172032      ['activation_189[0][0]']
#
#  batch_normalization_187 (Batch  (None, 8, 18, 192)  576         ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 8, 18, 256)  768         ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 8, 18, 256)   0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 18, 448)   0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 18, 2080)  933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 8, 18, 2080)  0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 18, 2080)  0           ['block8_7[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 8, 18, 192)  576         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 8, 18, 224)   129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 8, 18, 224)  672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 8, 18, 224)   0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 8, 18, 256)   172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 8, 18, 192)  576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 8, 18, 256)  768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 8, 18, 256)   0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 8, 18, 448)   0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 18, 2080)  933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 8, 18, 2080)  0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 18, 2080)  0           ['block8_8[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 8, 18, 192)  576         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 8, 18, 224)   129024      ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 8, 18, 224)  672         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 8, 18, 224)   0           ['batch_normalization_197[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 8, 18, 256)   172032      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 8, 18, 192)  576         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 8, 18, 256)  768         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 8, 18, 256)   0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 8, 18, 448)   0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 18, 2080)  933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 8, 18, 2080)  0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 18, 2080)  0           ['block8_9[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 8, 18, 192)  576         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 8, 18, 224)   129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 8, 18, 224)  672         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 8, 18, 224)   0           ['batch_normalization_201[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 8, 18, 192)   399360      ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 8, 18, 256)   172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 8, 18, 192)  576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 8, 18, 256)  768         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 8, 18, 192)   0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 8, 18, 256)   0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 8, 18, 448)   0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 18, 2080)  933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 8, 18, 2080)  0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 18, 1536)  3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 18, 1536)  4608       ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 18, 1536)  0           ['conv_7b_bn[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  xPooling2D)
#
#  batch_normalization_203 (Batch  (None, 1536)        6144        ['global_max_pooling2d[0][0]']
#  Normalization)
#
#  dense (Dense)                  (None, 256)          393472      ['batch_normalization_203[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 7)            1799        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 54,738,151
# Trainable params: 54,674,535
# Non-trainable params: 63,616
# __________________________________________________________________________________________________

# %%
history=model.fit(x=train_gen,   epochs=40, verbose=1,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Epoch 1/40
# 219/219 [==============================] - 156s 612ms/step - loss: 7.2178 - accuracy: 0.3454 - F1_score: 0.1456 - auc: 0.6986 - val_loss: 6.4221 - val_accuracy: 0.1129 - val_F1_score: 0.0000e+00 - val_auc: 0.5447
# Epoch 2/40
# 219/219 [==============================] - 128s 586ms/step - loss: 1.9522 - accuracy: 0.5011 - F1_score: 0.3346 - auc: 0.8401 - val_loss: 2.5930 - val_accuracy: 0.3357 - val_F1_score: 0.0037 - val_auc: 0.6693
# Epoch 3/40
# 219/219 [==============================] - 129s 587ms/step - loss: 1.6233 - accuracy: 0.5420 - F1_score: 0.4441 - auc: 0.8669 - val_loss: 2.2764 - val_accuracy: 0.3147 - val_F1_score: 0.0971 - val_auc: 0.7206
# Epoch 4/40
# 219/219 [==============================] - 129s 587ms/step - loss: 1.6232 - accuracy: 0.5400 - F1_score: 0.4362 - auc: 0.8667 - val_loss: 1504.8466 - val_accuracy: 0.1429 - val_F1_score: 0.1334 - val_auc: 0.4757
# Epoch 5/40
# 219/219 [==============================] - 129s 588ms/step - loss: 1.5703 - accuracy: 0.5406 - F1_score: 0.4317 - auc: 0.8701 - val_loss: 1.4985 - val_accuracy: 0.5295 - val_F1_score: 0.4429 - val_auc: 0.8928
# Epoch 6/40
# 219/219 [==============================] - 128s 584ms/step - loss: 1.5524 - accuracy: 0.5760 - F1_score: 0.4828 - auc: 0.8857 - val_loss: 34.6771 - val_accuracy: 0.5604 - val_F1_score: 0.5220 - val_auc: 0.8455
# Epoch 7/40
# 219/219 [==============================] - 129s 587ms/step - loss: 1.5397 - accuracy: 0.5874 - F1_score: 0.4912 - auc: 0.8876 - val_loss: 19.1013 - val_accuracy: 0.6603 - val_F1_score: 0.6083 - val_auc: 0.9058
# Epoch 8/40
# 219/219 [==============================] - 129s 589ms/step - loss: 1.4722 - accuracy: 0.6129 - F1_score: 0.5302 - auc: 0.8974 - val_loss: 1.3278 - val_accuracy: 0.6294 - val_F1_score: 0.5782 - val_auc: 0.9303
# Epoch 9/40
# 219/219 [==============================] - 129s 588ms/step - loss: 1.4553 - accuracy: 0.6083 - F1_score: 0.5402 - auc: 0.9006 - val_loss: 1.6277 - val_accuracy: 0.4765 - val_F1_score: 0.3513 - val_auc: 0.8621
# Epoch 10/40
# 219/219 [==============================] - 128s 586ms/step - loss: 1.5020 - accuracy: 0.5794 - F1_score: 0.4872 - auc: 0.8847 - val_loss: 1.3521 - val_accuracy: 0.6454 - val_F1_score: 0.5929 - val_auc: 0.9028
# Epoch 11/40
# 219/219 [==============================] - 128s 586ms/step - loss: 1.4352 - accuracy: 0.5837 - F1_score: 0.5150 - auc: 0.8882 - val_loss: 2.9380 - val_accuracy: 0.5025 - val_F1_score: 0.4213 - val_auc: 0.8305
# Epoch 12/40
# 219/219 [==============================] - 128s 584ms/step - loss: 1.4846 - accuracy: 0.5749 - F1_score: 0.4977 - auc: 0.8824 - val_loss: 80.2880 - val_accuracy: 0.1778 - val_F1_score: 0.0604 - val_auc: 0.5643
# Epoch 13/40
# 219/219 [==============================] - 128s 585ms/step - loss: 1.4281 - accuracy: 0.5957 - F1_score: 0.5134 - auc: 0.8960 - val_loss: 1.9631 - val_accuracy: 0.3536 - val_F1_score: 0.2632 - val_auc: 0.7495
# Epoch 14/40
# 219/219 [==============================] - 128s 586ms/step - loss: 1.4005 - accuracy: 0.6106 - F1_score: 0.5352 - auc: 0.8982 - val_loss: 214.6723 - val_accuracy: 0.5215 - val_F1_score: 0.4106 - val_auc: 0.7789
# Epoch 15/40
# 219/219 [==============================] - 128s 585ms/step - loss: 1.2669 - accuracy: 0.6400 - F1_score: 0.5882 - auc: 0.9171 - val_loss: 27.9324 - val_accuracy: 0.3996 - val_F1_score: 0.3339 - val_auc: 0.7797
# Epoch 16/40
# 219/219 [==============================] - 128s 584ms/step - loss: 1.2188 - accuracy: 0.6509 - F1_score: 0.6049 - auc: 0.9240 - val_loss: 2.2762 - val_accuracy: 0.6424 - val_F1_score: 0.6240 - val_auc: 0.9211
# Epoch 17/40
# 219/219 [==============================] - 129s 588ms/step - loss: 1.1526 - accuracy: 0.6826 - F1_score: 0.6448 - auc: 0.9343 - val_loss: 3.4079 - val_accuracy: 0.6563 - val_F1_score: 0.6198 - val_auc: 0.9177
# Epoch 18/40
# 219/219 [==============================] - 129s 587ms/step - loss: 1.1170 - accuracy: 0.6946 - F1_score: 0.6574 - auc: 0.9380 - val_loss: 1.2947 - val_accuracy: 0.7143 - val_F1_score: 0.6669 - val_auc: 0.9390
# Epoch 19/40
# 219/219 [==============================] - 129s 590ms/step - loss: 1.0437 - accuracy: 0.7100 - F1_score: 0.6765 - auc: 0.9464 - val_loss: 1.4720 - val_accuracy: 0.6593 - val_F1_score: 0.6112 - val_auc: 0.9325
# Epoch 20/40
# 219/219 [==============================] - 129s 590ms/step - loss: 1.0792 - accuracy: 0.7026 - F1_score: 0.6674 - auc: 0.9419 - val_loss: 1.3118 - val_accuracy: 0.6334 - val_F1_score: 0.5876 - val_auc: 0.9245
# Epoch 21/40
# 219/219 [==============================] - 129s 589ms/step - loss: 1.0240 - accuracy: 0.7180 - F1_score: 0.6871 - auc: 0.9484 - val_loss: 1.0568 - val_accuracy: 0.7033 - val_F1_score: 0.6918 - val_auc: 0.9489
# Epoch 22/40
# 219/219 [==============================] - 129s 588ms/step - loss: 0.9650 - accuracy: 0.7291 - F1_score: 0.7068 - auc: 0.9546 - val_loss: 1.4227 - val_accuracy: 0.5804 - val_F1_score: 0.5804 - val_auc: 0.8863
# Epoch 23/40
# 219/219 [==============================] - 127s 580ms/step - loss: 0.9567 - accuracy: 0.7211 - F1_score: 0.7074 - auc: 0.9545 - val_loss: 1.0051 - val_accuracy: 0.7512 - val_F1_score: 0.7276 - val_auc: 0.9556
# Epoch 24/40
# 219/219 [==============================] - 129s 590ms/step - loss: 0.9721 - accuracy: 0.7294 - F1_score: 0.7004 - auc: 0.9530 - val_loss: 1.4818 - val_accuracy: 0.5734 - val_F1_score: 0.5495 - val_auc: 0.8798
# Epoch 25/40
# 219/219 [==============================] - 128s 586ms/step - loss: 0.9493 - accuracy: 0.7400 - F1_score: 0.7175 - auc: 0.9544 - val_loss: 1.3535 - val_accuracy: 0.5724 - val_F1_score: 0.5518 - val_auc: 0.8972
# Epoch 26/40
# 219/219 [==============================] - 128s 586ms/step - loss: 0.9148 - accuracy: 0.7477 - F1_score: 0.7273 - auc: 0.9582 - val_loss: 1.1771 - val_accuracy: 0.6743 - val_F1_score: 0.6133 - val_auc: 0.9260
# Epoch 27/40
# 219/219 [==============================] - 128s 586ms/step - loss: 0.9296 - accuracy: 0.7374 - F1_score: 0.7189 - auc: 0.9576 - val_loss: 1.2756 - val_accuracy: 0.6084 - val_F1_score: 0.6039 - val_auc: 0.9194
# Epoch 28/40
# 219/219 [==============================] - 128s 583ms/step - loss: 0.9429 - accuracy: 0.7397 - F1_score: 0.7146 - auc: 0.9545 - val_loss: 2.0023 - val_accuracy: 0.4386 - val_F1_score: 0.4461 - val_auc: 0.7878
# Epoch 29/40
# 219/219 [==============================] - 128s 584ms/step - loss: 0.9265 - accuracy: 0.7417 - F1_score: 0.7173 - auc: 0.9556 - val_loss: 1.8353 - val_accuracy: 0.4765 - val_F1_score: 0.4566 - val_auc: 0.8638
# Epoch 30/40
# 219/219 [==============================] - 128s 585ms/step - loss: 0.8752 - accuracy: 0.7594 - F1_score: 0.7411 - auc: 0.9613 - val_loss: 1.1158 - val_accuracy: 0.7163 - val_F1_score: 0.6962 - val_auc: 0.9444
# Epoch 31/40
# 219/219 [==============================] - 128s 584ms/step - loss: 0.8672 - accuracy: 0.7451 - F1_score: 0.7365 - auc: 0.9611 - val_loss: 1.4673 - val_accuracy: 0.4615 - val_F1_score: 0.4049 - val_auc: 0.8673
# Epoch 32/40
# 219/219 [==============================] - 128s 585ms/step - loss: 0.8237 - accuracy: 0.7689 - F1_score: 0.7500 - auc: 0.9650 - val_loss: 1.1529 - val_accuracy: 0.6394 - val_F1_score: 0.6203 - val_auc: 0.9262
# Epoch 33/40
# 219/219 [==============================] - 128s 584ms/step - loss: 0.8143 - accuracy: 0.7737 - F1_score: 0.7591 - auc: 0.9671 - val_loss: 1.3191 - val_accuracy: 0.6583 - val_F1_score: 0.6306 - val_auc: 0.9159
# Epoch 34/40
# 219/219 [==============================] - 128s 585ms/step - loss: 0.8089 - accuracy: 0.7666 - F1_score: 0.7507 - auc: 0.9662 - val_loss: 1.1158 - val_accuracy: 0.7093 - val_F1_score: 0.6965 - val_auc: 0.9486
# Epoch 35/40
# 219/219 [==============================] - 129s 587ms/step - loss: 0.7601 - accuracy: 0.7877 - F1_score: 0.7776 - auc: 0.9709 - val_loss: 1.5121 - val_accuracy: 0.6314 - val_F1_score: 0.6241 - val_auc: 0.8843
# Epoch 36/40
# 219/219 [==============================] - 127s 582ms/step - loss: 0.7629 - accuracy: 0.8031 - F1_score: 0.7833 - auc: 0.9707 - val_loss: 1.0721 - val_accuracy: 0.6813 - val_F1_score: 0.6573 - val_auc: 0.9330
# Epoch 37/40
# 219/219 [==============================] - 129s 587ms/step - loss: 0.7798 - accuracy: 0.7903 - F1_score: 0.7760 - auc: 0.9700 - val_loss: 1.9914 - val_accuracy: 0.4386 - val_F1_score: 0.3953 - val_auc: 0.7774
# Epoch 38/40
# 219/219 [==============================] - 127s 581ms/step - loss: 0.7089 - accuracy: 0.8103 - F1_score: 0.8034 - auc: 0.9764 - val_loss: 1.5438 - val_accuracy: 0.5864 - val_F1_score: 0.5897 - val_auc: 0.8898
# Epoch 39/40
# 219/219 [==============================] - 129s 587ms/step - loss: 0.6849 - accuracy: 0.8217 - F1_score: 0.8099 - auc: 0.9774 - val_loss: 1.3866 - val_accuracy: 0.5365 - val_F1_score: 0.5136 - val_auc: 0.8917
# Epoch 40/40
# 219/219 [==============================] - 128s 583ms/step - loss: 0.6768 - accuracy: 0.8226 - F1_score: 0.8105 - auc: 0.9785 - val_loss: 0.8476 - val_accuracy: 0.7562 - val_F1_score: 0.7516 - val_auc: 0.9648

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.history['accuracy'], 'r', label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], 'g', label='Validation Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'], 'r', label='Training Loss')
#plt.plot(history.history['val_loss'], 'g', label='Validation Loss')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import confusion_matrix 

def predictor(test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    msg=f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}'
    print(msg)
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score, y_pred, y_true

errors, tests, error_list, error_pred_list, f1score, y_pred, y_true = predictor(test_gen)
# Out:
# 167/167 [==============================] - 17s 81ms/step
# there were 241 errors in 1002 tests for an accuracy of  75.95
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#            0     0.3654    0.5938    0.4524        32
#            1     0.5802    0.9038    0.7068        52
#            2     0.5439    0.5636    0.5536       110
#            3     0.5000    0.4545    0.4762        11
#            4     0.8882    0.8525    0.8700       671
#            5     0.5513    0.3839    0.4526       112
#            6     0.5652    0.9286    0.7027        14
#
#     accuracy                         0.7595      1002
#    macro avg     0.5706    0.6687    0.6020      1002
# weighted avg     0.7713    0.7595    0.7601      1002

# %%
model.save('IncepResnet.h5')
